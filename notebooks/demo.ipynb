# %% [markdown]
# # **Demo Rust integration**

# %%
from dprs import pydp

# %%
pydp.demo()
# Out:
# <module 'dprs.sim' from '/Users/cps/Projects/DPRS/.venv/lib/python3.14/site-packages/dprs/sim.cpython-314-darwin.so'>
# 1000 1000 200
#
# Grid width:  x=1000
# Grid height: y=1000
# Iterations:  n=200
#
#   Serial: 0.879s
# Parallel: 0.103s
# Speedup => 8.55x

# %%
from dprs import sim
print(sim)

n_x = 5_000
n_y = n_x
n_iterations = 200

sim.dp(n_x, n_y, n_iterations)
# Out:
# <module 'dprs.sim' from '/Users/cps/Projects/DPRS/.venv/lib/python3.14/site-packages/dprs/sim.cpython-314-darwin.so'>
# 5000 5000 200
#
# Grid width:  x=5000
# Grid height: y=5000
# Iterations:  n=200
#
#   Serial: 21.460s
# Parallel: 1.912s
# Speedup => 11.22x
# 'Done'
